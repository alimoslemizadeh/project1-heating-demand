# %%
import pandas as pd

gom = pd.read_csv("C:/Users/alimo/Desktop/icons/py/project1_heating_demand/data/building_geometry.csv")
uval = pd.read_csv("C:/Users/alimo/Desktop/icons/py/project1_heating_demand/data/building_uvalues.csv")
clim = pd.read_csv("C:/Users/alimo/Desktop/icons/py/project1_heating_demand/data/climate_hdd.csv")

print(gom)
print(uval)
print(clim)
# Out:
#   building_id  floor_area_m2  wall_area_m2  roof_area_m2  \
# 0         B01           1200           900           600
#
#    ground_floor_area_m2  wwr
# 0                   600  0.3
#    u_wall  u_roof  u_floor  u_window  infiltration_ach
# 0     0.3     0.2     0.25       1.3               0.5
#      city  hdd_kday
# 0  Berlin      3000
